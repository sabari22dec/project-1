# %%
num1=input()
num2=input()
my_name=("sabari")
# Out:
# 10
# 10.0

# %%
logged_in=True
logged_out=False
print("logged_in:",logged_in)
print("logged_out:",logged_out)
# Out:
# logged_in: True
# logged_out: False

# %%
username = input("enter your name: ")
# Out:
# enter your name: sabari

# %%
age=input()
print("my age is:",age)
# Out:
# 30
# my age is: 30

# %%
a=10
b=3
print(a+b)
# Out:
# 13

# %%
print(a-b)
# Out:
# 7

# %%
print(a*b)
# Out:
# 30

# %%
print(a/b)
# Out:
# 3.3333333333333335

# %%
print(a**b)
# Out:
# 1000

# %%
a=17
b=5
print(a%b)
# Out:
# 2

# %%
print(10==3)
# Out:
# False

# %%
print(10!=3)
# Out:
# True

# %%
print(10<3)
# Out:
# False

# %%
print(10<=3)
# Out:
# False

# %%
a="hellow"
b="hellow world"
print(a is b)
# Out:
# False

# %%
print(a is not b)
# Out:
# True

# %%
var1=("Apple is a fruit")
var2=("Apple")

# %%
print(var2 in var1)
# Out:
# True

# %%
print(var2 not in var2)
# Out:
# False
